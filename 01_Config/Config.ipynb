# %%
# Notebook : config
# Purpose  : configuration table paths for Procurement Project
# Author   : V R  Mutyala

CATALOG         = "Procurement"
BRONZE_SCHEMA   = "bronze"
SILVER_SCHEMA   = "silver"
GOLD_SCHEMA     = "gold"

# Bronze Tables

BRONZE_DEPARTMENTS              = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_departments"
BRONZE_EMPLOYEES                = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_employees"
BRONZE_SUPPLIERS                = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_suppliers"
BRONZE_PRODUCTS                 = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_products"
BRONZE_PURCHASE_REQUISITIONS    = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_purchase_requisitions"
BRONZE_PURCHASE_ORDERS          = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_purchase_orders"
BRONZE_GOODS_RECEIPTS           = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_goods_receipts"
BRONZE_INVOICES                 = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_invoices"
BRONZE_PAYMENTS                 = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_payments"

# Silver Tables
SILVER_DEPARTMENTS              = f"{CATALOG}.{SILVER_SCHEMA}.silver_departments"
SILVER_EMPLOYEES                = f"{CATALOG}.{SILVER_SCHEMA}.silver_employees"
SILVER_SUPPLIERS                = f"{CATALOG}.{SILVER_SCHEMA}.silver_suppliers"
SILVER_PRODUCTS                 = f"{CATALOG}.{SILVER_SCHEMA}.silver_products"
SILVER_PURCHASE_REQUISITIONS    = f"{CATALOG}.{SILVER_SCHEMA}.silver_purchase_requisitions"
SILVER_PURCHASE_ORDERS          = f"{CATALOG}.{SILVER_SCHEMA}.silver_purchase_orders"
SILVER_GOODS_RECEIPTS           = f"{CATALOG}.{SILVER_SCHEMA}.silver_goods_receipts"
SILVER_INVOICES                 = f"{CATALOG}.{SILVER_SCHEMA}.silver_invoices"
SILVER_PAYMENTS                 = f"{CATALOG}.{SILVER_SCHEMA}.silver_payments"

#Gold Tables
GOLD_DEPARTMENTS               = f"{CATALOG}.{GOLD_SCHEMA}.gold_departments"
GOLD_EMPLOYEES                 = f"{CATALOG}.{GOLD_SCHEMA}.gold_employees"
GOLD_SUPPLIERS                 = f"{CATALOG}.{GOLD_SCHEMA}.gold_suppliers"
GOLD_PRODUCTS                  = f"{CATALOG}.{GOLD_SCHEMA}.gold_products"
GOLD_PURCHASE_REQUISITIONS     = f"{CATALOG}.{GOLD_SCHEMA}.gold_purchase_requisitions"
GOLD_PURCHASE_ORDERS           = f"{CATALOG}.{GOLD_SCHEMA}.gold_purchase_orders"
GOLD_GOODS_RECEIPTS            = f"{CATALOG}.{GOLD_SCHEMA}.gold_goods_receipts"
GOLD_INVOICES                  = f"{CATALOG}.{GOLD_SCHEMA}.gold_invoices"
GOLD_PAYMENTS                  = f"{CATALOG}.{GOLD_SCHEMA}.gold_payments"

# Audit Schema

AUDIT_SCHEMA = "audit"

# Duplicate Records Audit Tables

AUDIT_DUPLICATE_DEPARTMENTS           = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_departments"
AUDIT_DUPLICATE_EMPLOYEES             = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_employees"
AUDIT_DUPLICATE_SUPPLIERS             = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_suppliers"
AUDIT_DUPLICATE_PRODUCTS              = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_products"
AUDIT_DUPLICATE_PURCHASE_REQUISITIONS = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_purchase_requisitions"
AUDIT_DUPLICATE_PURCHASE_ORDERS       = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_purchase_orders"
AUDIT_DUPLICATE_GOODS_RECEIPTS        = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_goods_receipts"
AUDIT_DUPLICATE_INVOICES              = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_invoices"
AUDIT_DUPLICATE_PAYMENTS              = f"{CATALOG}.{AUDIT_SCHEMA}.duplicate_payments"

# Invalid Records Audit Tables

AUDIT_INVALID_DEPARTMENTS             = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_departments"
AUDIT_INVALID_EMPLOYEES               = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_employees"
AUDIT_INVALID_SUPPLIERS               = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_suppliers"
AUDIT_INVALID_PRODUCTS                = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_products"
AUDIT_INVALID_PURCHASE_REQUISITIONS   = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_purchase_requisitions"
AUDIT_INVALID_PURCHASE_ORDERS         = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_purchase_orders"
AUDIT_INVALID_GOODS_RECEIPTS          = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_goods_receipts"
AUDIT_INVALID_INVOICES                = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_invoices"
AUDIT_INVALID_PAYMENTS                = f"{CATALOG}.{AUDIT_SCHEMA}.invalid_payments"

# Source File Configuration

LANDING_PATH = "/Volumes/procurement/landing/landing"

DEPARTMENTS_FILE            = f"{LANDING_PATH}/Departments.csv"
EMPLOYEES_FILE              = f"{LANDING_PATH}/Employees.csv"
SUPPLIERS_FILE              = f"{LANDING_PATH}/Suppliers.csv"
PRODUCTS_FILE               = f"{LANDING_PATH}/Products.csv"
PURCHASE_REQUISITIONS_FILE  = f"{LANDING_PATH}/Purchase_Requisitions.csv"
PURCHASE_ORDERS_FILE        = f"{LANDING_PATH}/Purchase_Orders.csv"
GOODS_RECEIPTS_FILE         = f"{LANDING_PATH}/Goods_Receipts.csv"
INVOICES_FILE               = f"{LANDING_PATH}/Invoices.csv"
PAYMENTS_FILE               = f"{LANDING_PATH}/Payments.csv"
